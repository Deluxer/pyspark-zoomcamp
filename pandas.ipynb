# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2021-01.csv.gz'

# %%
    green_tripdata_dtypes = {
        'VendorID': pd.Int64Dtype(), 
        'store_and_fwd_flag': str,
        'RatecodeID': pd.Int64Dtype(), 
        'PULocationID': pd.Int64Dtype(), 
        'DOLocationID': pd.Int64Dtype(), 
        'passenger_count': pd.Int64Dtype(),
        'trip_distance': float,
        'fare_amount': float,
        'extra': float,
        'mta_tax': float, 
        'tip_amount': float, 
        'tolls_amount': float, 
        'ehail_fee': float, 
        'improvement_surcharge': float, 
        'total_amount': float, 
        'payment_type': pd.Int64Dtype(), 
        'trip_type': float, 
        'congestion_surcharge': float
    }

    parse_dates = ['lpep_pickup_datetime', 'lpep_dropoff_datetime']

    pd.read_csv(url, sep=',', compression="gzip", dtype=green_tripdata_dtypes, parse_dates=parse_dates)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
df = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet")

# %%
df.to_csv('/home/gerardo/Documents/project/zoomcamp/data-engineering-zoomcamp/green_tripdata_2024-01.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_csv('/home/gerardo/Documents/project/zoomcamp/data-engineering-zoomcamp/yellow_tripdata_2021-07.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1          1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2          1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3          1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4          1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2024-01-01 00:54:16   2024-01-01 01:27:40              1.0
# 96         2  2024-01-01 00:13:58   2024-01-01 00:33:39              1.0
# 97         2  2024-01-01 00:35:53   2024-01-01 00:47:59              1.0
# 98         2  2024-01-01 00:50:28   2024-01-01 01:38:39              1.0
# 99         2  2024-01-01 00:18:24   2024-01-01 00:30:39              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %% [markdown]
# df = pd.read_parquet("yellow_tripdata_2024-01.parquet")

# %% [markdown]
# df.to_csv('/home/gerardo/Documents/proyect/zoomcamp/yellow_tripdata_2024-01.csv', index=False)

# %%
df = pd.read_csv('green_tripdata_2024-01.csv', nrows=100)

# %%
df = pd.read_csv('yellow_tripdata_2021-07.csv', nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-07-01 00:08:51   2021-07-01 00:13:05                1
# 1          1  2021-07-01 00:22:39   2021-07-01 00:25:58                1
# 2          1  2021-07-01 00:48:33   2021-07-01 00:54:58                1
# 3          1  2021-07-01 00:59:44   2021-07-01 01:07:09                1
# 4          1  2021-07-01 00:08:35   2021-07-01 00:16:28                0
# ..       ...                  ...                   ...              ...
# 95         1  2021-07-01 00:35:21   2021-07-01 00:40:49                1
# 96         2  2021-07-01 00:04:34   2021-07-01 00:20:15                2
# 97         2  2021-07-01 00:29:29   2021-07-01 00:36:14                3
# 98         1  2021-07-01 00:12:37   2021-07-01 00:22:54                1
# 99         1  2021-07-01 00:27:11   2021-07-01 00:35:23                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
df[df['tpep_pickup_datetime'] < '2021-07-01']
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 41         2  2021-06-30 23:59:47   2021-07-01 00:07:23                1
# 59         2  2021-06-30 23:58:29   2021-07-01 00:07:21                2
# 64         2  2021-06-30 23:58:56   2021-07-01 00:11:30                2
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 41           2.02           1                  N           162           114
# 59           1.72           1                  N           264           264
# 64           1.78           1                  N            79            90
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 41             1          8.0    0.5      0.5        2.36           0.0
# 59             2          8.5    0.5      0.5        0.00           0.0
# 64             1         10.0    0.5      0.5        2.76           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# ...

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_626040/1874911345.py in ?()
# ----> 1 df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       2 df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tpep_pickup_datetime'

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TEXT,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" FLOAT(53),
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type FLOAT(53),
# 	trip_type FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2024-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
len(df)
# Out:
# 100000

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 4.68 s, sys: 159 ms, total: 4.84 s
# Wall time: 7.15 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df =next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('Insert another chunk..., took %.3f second' % (t_end - t_start))
# Out:
# Insert another chunk..., took 7.034 second
# Insert another chunk..., took 7.046 second
# Insert another chunk..., took 7.135 second
# Insert another chunk..., took 6.965 second
# Insert another chunk..., took 7.141 second
# Insert another chunk..., took 7.080 second
# Insert another chunk..., took 7.031 second
# Insert another chunk..., took 7.149 second
# Insert another chunk..., took 7.398 second
# Insert another chunk..., took 7.200 second
# Insert another chunk..., took 6.927 second
# Insert another chunk..., took 6.910 second
# Insert another chunk..., took 6.906 second
# Insert another chunk..., took 6.900 second
# Insert another chunk..., took 7.011 second
# Insert another chunk..., took 7.021 second
# Insert another chunk..., took 6.724 second
# Insert another chunk..., took 6.997 second
# Insert another chunk..., took 6.977 second
# Insert another chunk..., took 6.993 second
# Insert another chunk..., took 7.078 second
# Insert another chunk..., took 6.928 second
# ...
